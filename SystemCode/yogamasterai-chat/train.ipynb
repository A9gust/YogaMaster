# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.6/876.6 kB 13.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.20 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                32.3/112.6 GB
# CPU                 Intel Xeon 2.30GHz
# CPU count           2
# GPU                 Tesla T4, 15102MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4>=1.23.0
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.4.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.4.1+cu121>=1.8.0
# torchvision         ✅ 0.19.1+cu121>=0.9.0
# tqdm                ✅ 4.66.5>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# ...

# %%
# !yolo task=pose mode=train model=yolo11m-pose.pt data='/content/drive/MyDrive/ultralytics-main/datasets/yoga_pose/yoga_pose.yaml' epochs=100 imgsz=640
# Out:
# ...
# 100% 40.5M/40.5M [00:00<00:00, 118MB/s]
# Ultralytics 8.3.20 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from ultralytics import YOLO

if __name__ == '__main__':
    model = YOLO('/content/drive/My Drive/ultralytics-main/ultralytics/cfg/models/11/yolo11-pose.yaml')
    model.train(data='/content/drive/My Drive/ultralytics-main/datasets/yoga_pose/yoga_pose.yaml',
                cache=False,
                imgsz=640,
                epochs=10,
                batch=8,
                close_mosaic=10,
                device='0',
                optimizer='SGD', # using SGD
                project='runs/train-pose',
                name='exp',
                )
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
